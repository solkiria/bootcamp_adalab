# %% [markdown]
# # Ejercicios Pair Programming - Modulo 2 - Sprint 1
# ## Lección 4 - Pandas IV: Filtrado de datos
# ### Judith Mellidez y Sonia Ruiz

# %% [markdown]
# Hoy seguiremos trabajando con el csv de ataques que exploramos ayer. Para eso, ayer guardasteis al final del pair programming al que le habíamos elimiando algunas columnas.
# Utilizad ese fichero. En la lección de hoy tendréis que ir contestando una serie de preguntas que os planteamos. Para ello tendréis que aplicar los conocimientos
# adquiridos en la clase invertida sobre como filtrar datos en el DataFrame y como reemplazar valores en el DataFrame.

# %% [markdown]
# 1. Cargad el csv que guardasteis ayer.
# Antes de seguir con las preguntas, este DataFrame está terriblemente sucio. En las próximas sesiones lo iremos limpiando. Para evitar posibles errores con los nulos vamos a eliminar todos los nulos del DataFrame. Para ello vamos a utilizar el método .dropna() de pandas. Tendréis que ejecutar la siguiente línea de código para eliminar los nulos del DataFrame y poder seguir haciendo el resto de los ejercicios.

# %% [markdown]
# - ¿Cuántas filas se han eliminado con esta línea de código?
# df.dropna(inplace = True)

# %%
#Importamos las librerias:
import pandas as pd
import numpy as np

# %%
#Creamos el dataframe a partir del archivo .csv .
attacks_lec3=pd.read_csv('data_pandas_lec3/attacks_lec3.csv')
attacks_lec3.head()
# Out:
#   case_number  unnamed:_0    year        type    country             area  \
# 0  2018.06.25           0  2018.0     Boating        USA       California
# 1  2018.06.18           1  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09           2  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08           3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04           4  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# ...

# %%
#Con el metodo shape exploramos las filas y columnas que tenemos en el DataFrame
shape1=attacks_lec3.shape
shape1
# Out:
# (6114, 14)

# %%
#Con el metodo info() exploramos nombre y numero de columnas, numero de valores not null y tipo de datos que tenemos en el DataFrame
attacks_lec3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6114 entries, 0 to 6113
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  6113 non-null   object
#  1   unnamed:_0   6114 non-null   int64
#  2   year         6114 non-null   float64
#  3   type         6110 non-null   object
#  4   country      6074 non-null   object
#  5   area         5706 non-null   object
#  6   location     5626 non-null   object
#  7   activity     5603 non-null   object
#  8   name         5914 non-null   object
#  9   sex_         5564 non-null   object
#  10  age          3448 non-null   object
#  11  time         2934 non-null   object
#  12  species_     3409 non-null   object
#  13  href         6114 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 668.8+ KB

# %%
#Resumen de datos estadisticos numericos
attacks_lec3.describe()
# Out:
#         unnamed:_0         year
# count  6114.000000  6114.000000
# mean   3065.554629  1968.831207
# std    1769.652139    43.745920
# min       0.000000  1801.000000
# 25%    1534.250000  1946.000000
# 50%    3066.500000  1980.000000
# 75%    4596.750000  2005.000000
# max    6131.000000  2018.000000

# %%
#Nos devuelve la cantidad de valores que son nulos en cada columna.
attacks_lec3.isnull().sum()
# Out:
# case_number       1
# unnamed:_0        0
# year              0
# type              4
# country          40
# area            408
# location        488
# activity        511
# name            200
# sex_            550
# age            2666
# time           3180
# species_       2705
# href              0
# dtype: int64

# %%
#Eliminamos las filas con valores nulos. Consideramos que no son buenas practicas eliminar los nulos sin observar
#  detenidamente el dataframe.
attacks_lec3.dropna(inplace=True)
attacks_lec3
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 6     2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 8     2018.05.26.b           8  2018.0  Unprovoked           USA
# 10      2018.05.24          10  2018.0    Provoked     AUSTRALIA
# 13    2018.05.13.a          13  2018.0     Invalid       ENGLAND
# ...            ...         ...     ...         ...           ...
# 5528    1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
# 5631    1894.11.28        5648  1894.0  Unprovoked     AUSTRALIA
# 5667    1892.03.02        5684  1892.0    Provoked     AUSTRALIA
# 5797    1880.11.25        5814  1880.0  Unprovoked     AUSTRALIA
# 5905    1868.05.13        5922  1868.0  Unprovoked         INDIA
#
#                        area                      location        activity  \
# 0                California   Oceanside, San Diego County        Paddling
# ...

# %%
#Obtenemos las forma del dataframe donde el primer elemento son las filas y el segundo las columnas.
shape2=attacks_lec3.shape
shape2
# Out:
# (1502, 14)

# %%
#Comprobamos que hemos eliminado los valores nulos.
attacks_lec3.isnull().sum()
# Out:
# case_number    0
# unnamed:_0     0
# year           0
# type           0
# country        0
# area           0
# location       0
# activity       0
# name           0
# sex_           0
# age            0
# time           0
# species_       0
# href           0
# dtype: int64

# %%
attacks_lec3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1502 entries, 0 to 5905
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  1502 non-null   object
#  1   unnamed:_0   1502 non-null   int64
#  2   year         1502 non-null   float64
#  3   type         1502 non-null   object
#  4   country      1502 non-null   object
#  5   area         1502 non-null   object
#  6   location     1502 non-null   object
#  7   activity     1502 non-null   object
#  8   name         1502 non-null   object
#  9   sex_         1502 non-null   object
#  10  age          1502 non-null   object
#  11  time         1502 non-null   object
#  12  species_     1502 non-null   object
#  13  href         1502 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 176.0+ KB

# %%
filas_eliminadas= shape1[0] - shape2[0]
print('Numero de filas eliminadas son:', filas_eliminadas)
# Out:
# Numero de filas eliminadas son: 4612

# %% [markdown]
# 2. ¿Cuál es el número de ataques que se han producido en Estados Unidos?

# %%
#Mostramos los valores unicos de la columna paises y se puede observar que estan en ingles y en mayusculas.
countries=attacks_lec3['country'].unique()
coutries1=np.sort(countries)
coutries1
# Out:
# array(['AMERICAN SAMOA', 'ARGENTINA', 'AUSTRALIA', 'BAHAMAS', 'BERMUDA',
#        'BRAZIL', 'BRITISH WEST INDIES', 'COLUMBIA', 'COSTA RICA',
#        'CROATIA', 'CUBA', 'ECUADOR', 'EGYPT', 'EL SALVADOR', 'ENGLAND',
#        'FEDERATED STATES OF MICRONESIA', 'FIJI', 'FRENCH POLYNESIA',
#        'GRAND CAYMAN', 'GREECE', 'GUAM', 'HONG KONG', 'INDIA',
#        'INDONESIA', 'IRAQ', 'ISRAEL', 'ITALY', 'JAMAICA', 'JAPAN',
#        'MALDIVES', 'MARSHALL ISLANDS', 'MAURITIUS', 'MEXICO',
#        'MICRONESIA', 'MOZAMBIQUE', 'NEW BRITAIN', 'NEW CALEDONIA',
#        'NEW ZEALAND', 'NORTH PACIFIC OCEAN', 'OKINAWA', 'PACIFIC OCEAN',
#        'PALAU', 'PANAMA', 'PAPUA NEW GUINEA', 'PHILIPPINES', 'REUNION',
#        'RUSSIA', 'SCOTLAND', 'SENEGAL', 'SEYCHELLES', 'SOLOMON ISLANDS',
#        'SOUTH AFRICA', 'SOUTH KOREA', 'SPAIN', 'ST. MAARTIN', 'TAIWAN',
#        'THAILAND', 'TONGA', 'TURKS & CAICOS', 'UNITED KINGDOM', 'USA',
#        'VANUATU', 'VENEZUELA', 'VIETNAM'], dtype=object)

# %%
#Mostramos solos datos del dataframe con los ataques en el pais "USA".
attacks_USA=attacks_lec3[attacks_lec3['country']== 'USA']
attacks_USA
# Out:
#        case_number  unnamed:_0    year        type country           area  \
# 0       2018.06.25           0  2018.0     Boating     USA     California
# 8     2018.05.26.b           8  2018.0  Unprovoked     USA        Florida
# 35      2018.03.31          35  2018.0  Unprovoked     USA         Hawaii
# 53      2017.12.31          53  2017.0  Unprovoked     USA         Hawaii
# 60      2017.11.24          60  2017.0  Unprovoked     USA     California
# ...            ...         ...     ...         ...     ...            ...
# 4731    1941.06.15        4743  1941.0    Provoked     USA       New York
# 4734    1941.03.09        4746  1941.0    Provoked     USA     California
# 4862    1936.07.25        4874  1936.0  Unprovoked     USA  Massachusetts
# 5136    1926.07.08        5148  1926.0  Unprovoked     USA     California
# 5297    1916.07.01        5311  1916.0  Unprovoked     USA     New Jersey
#
#                                                location  \
# ...

# %%
shape3= attacks_USA.shape
print('El numero de ataques en Estados Unidos ha sido:', shape3[0])
# Out:
# El numero de ataques en Estados Unidos ha sido: 719

# %% [markdown]
# 3. ¿Y en España?

# %% [markdown]
# - 3.1 ¿En qué regiones se han producido los ataques (columna location) ?

# %%
#Mostramos solos datos del dataframe con los ataques en el pais "SPAIN".
attacks_SPAIN=attacks_lec3[attacks_lec3['country']== 'SPAIN']
attacks_SPAIN
# Out:
#        case_number  unnamed:_0    year        type country  \
# 98    2017.08.26.b          98  2017.0     Invalid   SPAIN
# 233     2016.07.29         234  2016.0  Unprovoked   SPAIN
# 377   2015.08.18.a         378  2015.0     Invalid   SPAIN
# 1007  2010.07.16.b        1011  2010.0    Provoked   SPAIN
# 2469    1993.09.03        2476  1993.0  Unprovoked   SPAIN
#
#                      area                        location  activity  \
# 98              Castellón                 Grao de Moncofa  Swimming
# 233     Alicante Province                Arenales del Sol  Swimming
# 377              Alicante        Poniente Beach, Benidorm  Swimming
# 1007  Grand Canary Island       Sardina del Norte, Gáldar  Swimming
# 2469         Costa Blanca  Playa de las Arenas, Valencia   Swimming
#
#                                      name sex_ age    time  \
# 98                                 female    F  11  Midday
# 233                                  male    M  40   11h30
# ...

# %%
shape4= attacks_SPAIN.shape
print('El numero de ataques en España ha sido:', shape4 [0])
# Out:
# El numero de ataques en España ha sido: 5

# %%
attacks_loc_SPAIN=attacks_SPAIN['location'].unique()
print('Las regiones donde se han producido los ataques en España son:', attacks_loc_SPAIN)
# Out:
# Las regiones donde se han producido los atques en España son: ['Grao de Moncofa' 'Arenales del Sol' 'Poniente Beach, Benidorm'
#  'Sardina del Norte, Gáldar' 'Playa de las Arenas, Valencia ']

# %% [markdown]
#  - 3.2 ¿Cuántos ataques se han producido en cada área (columna area?

# %%
#aplicamos el metodo '.value_counts()' para extraer la informacion especifica del numero de ataques sufridos por area.
attacks_area_SPAIN=attacks_SPAIN['area'].value_counts()
attacks_area_SPAIN
# Out:
# Castellón              1
# Alicante Province      1
# Alicante               1
# Grand Canary Island    1
# Costa Blanca           1
# Name: area, dtype: int64

# %% [markdown]
# 4. Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos.
# 📌 Nota Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin().
# Hacedlo con ambas herramientas.

# %%
#Un metodo para crear el DataFrame solicitado seria:
attacks_USA_AUSTRALIA=attacks_lec3[(attacks_lec3['country']== 'USA') | (attacks_lec3['country'] == 'AUSTRALIA')] 
attacks_USA_AUSTRALIA
# Out:
#        case_number  unnamed:_0    year        type    country  \
# 0       2018.06.25           0  2018.0     Boating        USA
# 8     2018.05.26.b           8  2018.0  Unprovoked        USA
# 10      2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21    2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 35      2018.03.31          35  2018.0  Unprovoked        USA
# ...            ...         ...     ...         ...        ...
# 5359    1912.01.26        5375  1912.0  Unprovoked  AUSTRALIA
# 5481    1905.03.26        5498  1905.0  Unprovoked  AUSTRALIA
# 5631    1894.11.28        5648  1894.0  Unprovoked  AUSTRALIA
# 5667    1892.03.02        5684  1892.0    Provoked  AUSTRALIA
# 5797    1880.11.25        5814  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 0            California                     Oceanside, San Diego County
# 8               Florida                    Cocoa Beach, Brevard  County
# ...

# %%
#Otro metodo que podemos utilizar para crear el DataFrame es '.isin()'.
attacks_USA_AUSTRALIA_isn=attacks_lec3[attacks_lec3['country'].isin(['USA','AUSTRALIA'])]
attacks_USA_AUSTRALIA_isn
# Out:
#        case_number  unnamed:_0    year        type    country  \
# 0       2018.06.25           0  2018.0     Boating        USA
# 8     2018.05.26.b           8  2018.0  Unprovoked        USA
# 10      2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21    2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 35      2018.03.31          35  2018.0  Unprovoked        USA
# ...            ...         ...     ...         ...        ...
# 5359    1912.01.26        5375  1912.0  Unprovoked  AUSTRALIA
# 5481    1905.03.26        5498  1905.0  Unprovoked  AUSTRALIA
# 5631    1894.11.28        5648  1894.0  Unprovoked  AUSTRALIA
# 5667    1892.03.02        5684  1892.0    Provoked  AUSTRALIA
# 5797    1880.11.25        5814  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 0            California                     Oceanside, San Diego County
# 8               Florida                    Cocoa Beach, Brevard  County
# ...

# %% [markdown]
# - 4.1 ¿Cuántos ataques se han producido en cada país?

# %%
#Empleando el metodo ".value_counts()" obtenemos el recuento de filas para cada valor unico de la columna especificada.
attacks_cases_USA_AUSTRALIA=attacks_USA_AUSTRALIA['country'].value_counts()
attacks_cases_USA_AUSTRALIA
# Out:
# USA          719
# AUSTRALIA    324
# Name: country, dtype: int64

# %% [markdown]
# - 4.2 ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?

# %%
#Comprobamos todas las actividades registradas en el momento del ataque.
attasck_act_USA_AUS=attacks_USA_AUSTRALIA['activity'].unique()
attasck_act_USA_AUS
# Out:
# array(['Paddling', 'Walking', 'Feeding sharks', 'Surfing',
#        'Stand-Up Paddleboarding', 'Wading', 'Swimming', 'Spearfishing',
#        'Kayaking / Fishing', 'Snorkeling', 'SUP', 'Fishing', 'Kayaking',
#        'Body boarding', 'Scuba Diving', 'Surf fishing', 'Floating',
#        'SUP Foil boarding', 'Kite surfing', 'Floating in tube',
#        'Standing', 'Diving', 'Teasing a shark', 'Paddle boarding',
#        'Kayak Fishing', 'Surf-skiing', 'Scallop diving on hookah',
#        'Body boarding ', 'Playing in the water', 'Boogie boarding',
#        'Playing', 'Surf skiing ', 'Standing / Snorkeling', 'Rowing',
#        'Shark fishing', 'Fishing ', 'Kayaking ', 'Body surfing',
#        'Diving for lobsters', 'Kiteboarding', 'Diving ',
#        'Diving for Abalone', 'Casting a net', 'Boogie Boarding',
#        'Playing in the surf', 'Bodyboarding',
#        'Swimming or boogie boarding', 'Free diving ',
#        'Sitting in the water', 'Scuba diving', 'Diving, feeding sharks',
# ...

# %%
#No ha habido ataques en Australia mientras practicaban Paddling
attacks_pad_AUSTRALIA=attacks_USA_AUSTRALIA[(attacks_USA_AUSTRALIA['country']== 'AUSTRALIA')&(attacks_USA_AUSTRALIA['activity']== 'Paddling')]
attacks_pad_AUSTRALIA
# Out:
# Empty DataFrame
# Columns: [case_number, unnamed:_0, year, type, country, area, location, activity, name, sex_, age, time, species_, href]
# Index: []

# %% [markdown]
# - 4.3 ¿Cuántos ataques se han producido en Australia antes del 2000?

# %%
#Filtramos los datos del dataframe para mostrar solo aquellos del pais "AUSTRALIA", antes del año 2000 (no incluido).
attacks_bf2000_AUS=attacks_USA_AUSTRALIA[(attacks_USA_AUSTRALIA['country']== 'AUSTRALIA')&(attacks_USA_AUSTRALIA['year']<2000)]
attacks_bf2000_AUS
# Out:
#         case_number  unnamed:_0    year        type    country  \
# 2116     1999.05.29        2123  1999.0  Unprovoked  AUSTRALIA
# 2129     1999.02.23        2136  1999.0  Unprovoked  AUSTRALIA
# 2174   1998.06.28.a        2181  1998.0  Unprovoked  AUSTRALIA
# 2194  1998.01.28.R         2201  1998.0     Invalid  AUSTRALIA
# 2207     1997.11.09        2214  1997.0  Unprovoked  AUSTRALIA
# ...             ...         ...     ...         ...        ...
# 5359     1912.01.26        5375  1912.0  Unprovoked  AUSTRALIA
# 5481     1905.03.26        5498  1905.0  Unprovoked  AUSTRALIA
# 5631     1894.11.28        5648  1894.0  Unprovoked  AUSTRALIA
# 5667     1892.03.02        5684  1892.0    Provoked  AUSTRALIA
# 5797     1880.11.25        5814  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 2116    South Australia                  Hardwicke Bay, Yorke Peninsula
# ...

# %% [markdown]
# - 4.4 ¿Y después del 2000?

# %%
#Filtramos los datos del dataframe para mostrar solo aquellos del pais "AUSTRALIA", a partir del año 2000 (no incluido).
attacks_af2000_AUS=attacks_USA_AUSTRALIA[(attacks_USA_AUSTRALIA['country']== 'AUSTRALIA')&(attacks_USA_AUSTRALIA['year']>2000)]
attacks_af2000_AUS
# Out:
#        case_number  unnamed:_0    year        type    country  \
# 10      2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21    2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 36      2018.03.14          36  2018.0  Unprovoked  AUSTRALIA
# 37    2018.03.09.b          37  2018.0  Unprovoked  AUSTRALIA
# 38    2018.03.09.a          38  2018.0  Unprovoked  AUSTRALIA
# ...            ...         ...     ...         ...        ...
# 1876    2002.02.07        1883  2002.0     Boating  AUSTRALIA
# 1877  2002.01.30.b        1884  2002.0  Unprovoked  AUSTRALIA
# 1888    2001.10.02        1895  2001.0  Unprovoked  AUSTRALIA
# 1961  2001.04.02.a        1968  2001.0  Unprovoked  AUSTRALIA
# 1969    2001.02.04        1976  2001.0  Unprovoked  AUSTRALIA
#
#                    area                       location        activity  \
# 10           Queensland                Cairns Aquarium  Feeding sharks
# 21    Western Australia        Surfers Point, Prevelly         Surfing
# ...

# %% [markdown]
# 5. Extraed unicamente los ataques a mujeres.

# %%
#Filtramos los datos del dataframe por sexo femenino.
attacks_F= attacks_lec3[attacks_lec3['sex_']== 'F']
attacks_F
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 40      2018.02.23          40  2018.0  Unprovoked     AUSTRALIA
# 53      2017.12.31          53  2017.0  Unprovoked           USA
# 71      2017.10.22          71  2017.0  Unprovoked     AUSTRALIA
# 75      2017.10.05          75  2017.0  Unprovoked           USA
# ...            ...         ...     ...         ...           ...
# 4151    1958.04.05        4163  1958.0  Unprovoked  SOUTH AFRICA
# 4170    1957.12.30        4182  1957.0  Unprovoked  SOUTH AFRICA
# 4678    1942.12.26        4690  1942.0  Unprovoked     AUSTRALIA
# 4706    1942.01.04        4718  1942.0  Unprovoked     AUSTRALIA
# 4913  1934.12.31.b        4925  1934.0  Unprovoked     AUSTRALIA
#
#                  area                                           location  \
# 0          California                        Oceanside, San Diego County
# ...

# %% [markdown]
# 6. ¿Cuántas mujeres fueron atacadas en España?

# %%
#Filtramos los datos del dataframe por sexo femenino y ocurridos en el pais "SPAIN".
attacks_F_SPAIN= attacks_lec3[(attacks_lec3['sex_']== 'F')&(attacks_lec3['country']=='SPAIN')]
attacks_F_SPAIN
# Out:
#      case_number  unnamed:_0    year     type country       area  \
# 98  2017.08.26.b          98  2017.0  Invalid   SPAIN  Castellón
#
#            location  activity    name sex_ age    time  \
# 98  Grao de Moncofa  Swimming  female    F  11  Midday
#
#                           species_  \
# 98  Shark involvement questionable
#
#                                                  href
# 98  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# 7. Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006. Utilizad el método isin() para resolver este ejercicio.

# %%
#Mostramos los ataque sproducidos en los años 1997, 2000 y 2006, para ello utilizamos el metodo ".isin()".
attacks_years=attacks_lec3[attacks_lec3['year'].isin([2000,1997,2006])]
attacks_years
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 1407    2006.12.18        1412  2006.0  Unprovoked     AUSTRALIA
# 1408    2006.12.11        1413  2006.0  Unprovoked   NEW ZEALAND
# 1409    2006.12.10        1414  2006.0  Unprovoked           USA
# 1410    2006.12.06        1415  2006.0    Provoked  SOUTH AFRICA
# 1411    2006.12.02        1416  2006.0  Unprovoked     AUSTRALIA
# ...            ...         ...     ...         ...           ...
# 2246  1997.05.31.b        2253  1997.0  Unprovoked           USA
# 2247  1997.05.31.a        2254  1997.0  Unprovoked           USA
# 2252  1997.02.28.a        2259  1997.0  Unprovoked     AUSTRALIA
# 2256    1997.01.25        2263  1997.0  Unprovoked     AUSTRALIA
# 2257    1997.01.20        2264  1997.0  Unprovoked     AUSTRALIA
#
#                    area                              location       activity  \
# 1407           Victoria                Winki Pop, Bells Beach        Surfing
# ...

# %% [markdown]
# 8. Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma se puede convertir
# en algo difícil. En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que
# contenga white o White). Usad el método str.contains() para resolver este ejercicio.

# %%
#Empleando el metodo ".std.contains()" mostramos las filas que contienen en la columna especificada el patron regex que le introducimos.
attacks_species=attacks_lec3[attacks_lec3['species_'].str.contains('\w+hite',case =False, regex=True)]
attacks_species
# Out:
#      case_number  unnamed:_0    year        type       country  \
# 0     2018.06.25           0  2018.0     Boating           USA
# 24    2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
# 34    2018.04.03          34  2018.0  Unprovoked  SOUTH AFRICA
# 40    2018.02.23          40  2018.0  Unprovoked     AUSTRALIA
# 60    2017.11.24          60  2017.0  Unprovoked           USA
# ...          ...         ...     ...         ...           ...
# 5212  1922.05.06        5225  1922.0  Unprovoked  SOUTH AFRICA
# 5216  1922.03.02        5229  1922.0  Unprovoked     AUSTRALIA
# 5218  1922.02.04        5231  1922.0  Unprovoked     AUSTRALIA
# 5297  1916.07.01        5311  1916.0  Unprovoked           USA
# 5528  1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
#
#                        area                            location  \
# 0                California         Oceanside, San Diego County
# 24    Western Cape Province      Robberg Beach, Plettenberg Bay
# ...

# %% [markdown]
# 9. Extraed ahora los ataques por tiburón blanco o tigre. Utilizad el método str.contains() para resolver este ejercicio.

# %%
attacks_species=attacks_lec3[(attacks_lec3['species_'].str.contains('\w+hite',case =False, regex=True))|(attacks_lec3['species_'].str.contains('[T|t]iger',case =False, regex=True))]
attacks_species
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 6     2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 18    2018.04.28.b          18  2018.0  Unprovoked    COSTA RICA
# 23      2018.04.23          23  2018.0  Unprovoked      MALDIVES
# 24      2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
# ...            ...         ...     ...         ...           ...
# 5212    1922.05.06        5225  1922.0  Unprovoked  SOUTH AFRICA
# 5216    1922.03.02        5229  1922.0  Unprovoked     AUSTRALIA
# 5218    1922.02.04        5231  1922.0  Unprovoked     AUSTRALIA
# 5297    1916.07.01        5311  1916.0  Unprovoked           USA
# 5528    1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
#
#                        area                        location  \
# 0                California     Oceanside, San Diego County
# 6                Pernambuco           Piedade Beach, Recife
# ...

# %% [markdown]
# 10. Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI. Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

# %%
#Utilizamos el metodo de numpy 'np.where()' mediante el cual nos permite reemplazar los elementos que cumplan la condidicion especificada por los datos que le indicamos.
attacks_lec3['siglo']=np.where(attacks_lec3['year']<2000, 'siglo-XX','siglo-XXI')
attacks_lec3
# Out:
#        case_number  unnamed:_0    year        type       country  \
# 0       2018.06.25           0  2018.0     Boating           USA
# 6     2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 8     2018.05.26.b           8  2018.0  Unprovoked           USA
# 10      2018.05.24          10  2018.0    Provoked     AUSTRALIA
# 13    2018.05.13.a          13  2018.0     Invalid       ENGLAND
# ...            ...         ...     ...         ...           ...
# 5528    1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
# 5631    1894.11.28        5648  1894.0  Unprovoked     AUSTRALIA
# 5667    1892.03.02        5684  1892.0    Provoked     AUSTRALIA
# 5797    1880.11.25        5814  1880.0  Unprovoked     AUSTRALIA
# 5905    1868.05.13        5922  1868.0  Unprovoked         INDIA
#
#                        area                      location        activity  \
# 0                California   Oceanside, San Diego County        Paddling
# ...

# %% [markdown]
# 11. Guardad como un archivo csv nuevo. Lo usaremos en el pair programming de mañana.

# %%
#Efecutamos el guardado del archivo en un csv nuevo asociado a la lecccion 4 con los ejercicios realizados en dicha leccion.
attacks_lec3.to_csv('Data_lecc4_pandas/attacks_lec4.csv')

# %% [markdown]
# Happy coding 🦈
