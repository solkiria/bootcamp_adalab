# %% [markdown]
# # Ejercicios Pair Programming - Modulo 2 - Sprint 1
# ## Lección 3 - Pandas III: Métodos Pandas
# ### Judith Mellidez y Sonia Ruiz

# %% [markdown]
# De aquí en adelante, vamos a trabajar con el mismo dataset. Se trata de un conjunto de datos que contiene información sobre ataques de tiburones en distintas partes del mundo. ¿El problema de los datos? Están terriblemente sucios!!! En las próximas lecciones iremos limpiando este csv y sacaremos conclusiones usando la visualización.
#
# ### __Tareas a realizar en este pair programming__
#
# 0. Desgargar el archivo attacks.csv del GitBook, en el apartado PairProgramming Pandas III.
# 1. Cargar el dataset
#
# 💡 Pista Si hacemos la carga del dataset sin el parámetro encoding nos puede dar error (puede que no os de error, si es así menos problemas!). Aquí tenéis una lista de los encodings disponibles en pandas. Buscad por los encoding de tipo ISO.

# %%
#Importamos la libreria Pandas y cremos el dataframe a partir del fichero .csv .
import pandas as pd
attacks=pd.read_csv('data_pandas_lec3/attacks.csv', encoding='utf-8')
attacks.head()
#especificamos el encoding, aunquen no nos ha dado error en un principio.
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# 2. Haced una exploración básica del DataFrame:
# - ¿Cuántas filas y columnas tiene el DataFrame?

# %%
#Obtenemos la forma del dataframe
attacks_shape=attacks.shape
print(f'El DataFrame Attacks tiene {attacks_shape[0]} filas y {attacks_shape[1]} columnas')
# Out:
# El DataFrame Attacks tiene 6114 filas y 22 columnas

# %% [markdown]
# - Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.
# Mostrad 2 filas al azar del DataFrame.

# %%
print('Las 5 primeras filas son:')
attacks.head()
# Out:
# Las 5 primeras filas son:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
print('Las 5 ultimas filas son:')
attacks.tail()
# Out:
# Las 5 ultimas filas son:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 6109    New South Wales    Georges Head, off Port Jackson
# 6110     South Carolina                    Off Charleston
# 6111  Western Australia  Hamelin Harbour, at Faure Island
# 6112                NaN                               NaN
# 6113                NaN                               NaN
#
#                              Activity                             Name Sex   \
# 6109                              NaN                             boat  NaN
# ...

# %%
print('Dos de sus filas son:')
attacks.sample(2)
#El metodo ".sample()" nos muestra el numero que le especifiquemos al azar.
# Out:
# Dos de sus filas son:
#       Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 5188        5200  1923.08.08  1923.0  Unprovoked     GUYANA  Demerara County
# 5015        5027  1931.01.07  1931.0  Unprovoked  AUSTRALIA       Queensland
#
#                       Location  Activity           Name Sex   ...  \
# 5188   Off the Demerara River    Fishing  Charles Blair    M  ...
# 5015  Yeppoon, near Ross Creek  Swimming  Stanley Roser    M  ...
#
#               Species                              Investigator or Source  \
# 5188               NaN                        Gleaner (Jamaica), 9/6/1923
# 5015  1.5 m [5'] shark  Canberra Times, 1/9/1931; V.M. Coppleson.Q8. (...
#
#                        pdf                                       href formula  \
# 5188  1923.08.08-Blair.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5015  1931.01.07-Roser.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# ...

# %% [markdown]
# - ¿Cuál es el nombre de las columnas del DataFrame?

# %%
print('Los nombres de las columnas son:')
nombres_columnas=attacks.columns
nombres_columnas
# Out:
# Los nombres de las columnas son:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# - ¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.

# %%
print('Los principales estadisticos de las variables numericas son:')
attacks.describe()
# Out:
# Los principales estadisticos de las variables numericas son:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000
# 50%    3066.500000  1980.000000     3236.500000
# 75%    4596.750000  2005.000000     4768.750000
# max    6131.000000  2018.000000     6303.000000

# %%
print('Los principales estadisticos de las variables categoricas son:')
attacks.describe(include='object')
# Out:
# Los principales estadisticos de las variables categoricas son:
#        Case Number        Type Country     Area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 Location Activity  Name  Sex    Age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              Time     Species  Investigator or Source                     pdf  \
# count        2934         3409                   6098                    6114
# unique        366         1529                   4837                    6105
# top     Afternoon  White shark         C. Moore, GSAF  1898.00.00.R-Syria.pdf
# ...

# %% [markdown]
# - ¿Cuál es el porcentaje de valores nulos en cada columna?

# %%
#primero obtenemos los valores nulos por cada columna, dandonos un valor de la suma de los nulos en esa columna.
attacks.isnull().sum()
# Out:
# Unnamed: 0                   0
# Case Number                  1
# Year                         0
# Type                         4
# Country                     40
# Area                       408
# Location                   488
# Activity                   511
# Name                       200
# Sex                        550
# Age                       2666
# Time                      3180
# Species                   2705
# Investigator or Source      16
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6113
# Unnamed: 23               6112
# dtype: int64

# %%
#efectuamos el porcetaje a cada uno de los valores que hemos obtenido de cada una de las columnas de la siguiente manera:
attacks.isnull().sum()/6113*100
# Out:
# Unnamed: 0                  0.000000
# Case Number                 0.016359
# Year                        0.000000
# Type                        0.065434
# Country                     0.654343
# Area                        6.674301
# Location                    7.982987
# Activity                    8.359234
# Name                        3.271716
# Sex                         8.997219
# Age                        43.611974
# Time                       52.020285
# Species                    44.249959
# Investigator or Source      0.261737
# pdf                         0.000000
# href formula                0.016359
# href                        0.000000
# Case Number.1               0.000000
# Case Number.2               0.000000
# original order              0.000000
# Unnamed: 22               100.000000
# Unnamed: 23                99.983641
# dtype: float64

# %% [markdown]
# - Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.

# %%
#obtenemos los tipos de datos de cada una de las columnas para conocer las columnas
#  con datos numericos y poder generar los diccionarios con los valores unicos y sus frecuencias.
attacks.dtypes
# Out:
# Unnamed: 0                  int64
# Case Number                object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
#creacion de diccionario de la variable numerica 'Unnamed: 0'.
dicc_unnamed=dict(attacks['Unnamed: 0'].value_counts())
dicc_unnamed
# Out:
# {0: 1,
#  4084: 1,
#  4093: 1,
#  4092: 1,
#  4091: 1,
#  4090: 1,
#  4089: 1,
#  4088: 1,
#  4087: 1,
#  4086: 1,
#  4085: 1,
#  4083: 1,
#  4095: 1,
#  4082: 1,
#  4081: 1,
#  4080: 1,
#  4079: 1,
#  4078: 1,
#  4077: 1,
#  4076: 1,
#  4075: 1,
#  4074: 1,
#  4094: 1,
#  4096: 1,
#  4072: 1,
#  4108: 1,
#  4117: 1,
#  4116: 1,
#  4115: 1,
#  4114: 1,
#  4113: 1,
#  4112: 1,
#  4111: 1,
#  4110: 1,
#  4109: 1,
#  4107: 1,
#  4097: 1,
#  4106: 1,
#  4105: 1,
#  4104: 1,
#  4103: 1,
#  4102: 1,
#  4101: 1,
#  4100: 1,
#  4099: 1,
#  4098: 1,
#  4073: 1,
#  4071: 1,
#  4119: 1,
#  4036: 1,
#  4045: 1,
#  4044: 1,
#  4043: 1,
#  4042: 1,
#  4041: 1,
#  4040: 1,
#  4039: 1,
#  4038: 1,
#  4037: 1,
#  4035: 1,
#  4047: 1,
#  4034: 1,
#  4033: 1,
#  4032: 1,
#  4031: 1,
#  4030: 1,
#  4029: 1,
#  4028: 1,
#  4027: 1,
#  4026: 1,
#  4046: 1,
#  4048: 1,
#  4070: 1,
#  4060: 1,
#  4069: 1,
#  4068: 1,
#  4067: 1,
#  4066: 1,
#  4065: 1,
#  4064: 1,
#  4063: 1,
#  4062: 1,
#  4061: 1,
# ...

# %%
#creacion de diccionario de la variable numerica 'Year'.
dicc_year=dict(attacks['Year'].value_counts())
dicc_year
# Out:
# {2015.0: 143,
#  2017.0: 136,
#  2016.0: 130,
#  2011.0: 128,
#  2014.0: 126,
#  2008.0: 122,
#  2013.0: 121,
#  2009.0: 119,
#  2012.0: 116,
#  2007.0: 112,
#  2006.0: 102,
#  2005.0: 102,
#  2010.0: 101,
#  2000.0: 97,
#  1960.0: 93,
#  1959.0: 93,
#  2001.0: 92,
#  2003.0: 92,
#  2004.0: 92,
#  2002.0: 88,
#  1962.0: 85,
#  1961.0: 78,
#  1995.0: 76,
#  1999.0: 66,
#  1964.0: 66,
#  1998.0: 65,
#  1996.0: 61,
#  1963.0: 61,
#  1966.0: 57,
#  1997.0: 57,
#  1992.0: 56,
#  1993.0: 56,
#  1994.0: 56,
#  1988.0: 55,
#  1958.0: 54,
#  2018.0: 53,
#  1989.0: 53,
#  1956.0: 51,
#  1965.0: 51,
#  1983.0: 49,
#  1975.0: 49,
#  1981.0: 49,
#  1967.0: 48,
#  1968.0: 47,
#  1955.0: 43,
#  1950.0: 43,
#  1954.0: 42,
#  1970.0: 42,
#  1957.0: 41,
#  1984.0: 41,
#  1942.0: 41,
#  1982.0: 40,
#  1976.0: 39,
#  1986.0: 39,
#  1929.0: 38,
#  1974.0: 38,
#  1991.0: 38,
#  1985.0: 37,
#  1990.0: 37,
#  1953.0: 36,
#  1972.0: 35,
#  1987.0: 35,
#  1980.0: 34,
#  1951.0: 32,
#  1936.0: 32,
# ...

# %%
#creacion de diccionario de la variable numerica 'original order'.
dicc_original_order=dict(attacks['original order'].value_counts())
dicc_original_order
# Out:
# {569.0: 2,
#  6303.0: 1,
#  2208.0: 1,
#  2210.0: 1,
#  2211.0: 1,
#  2212.0: 1,
#  2213.0: 1,
#  2214.0: 1,
#  2215.0: 1,
#  2216.0: 1,
#  2217.0: 1,
#  2218.0: 1,
#  2219.0: 1,
#  2220.0: 1,
#  2221.0: 1,
#  2222.0: 1,
#  2223.0: 1,
#  2224.0: 1,
#  2225.0: 1,
#  2226.0: 1,
#  2227.0: 1,
#  2228.0: 1,
#  2229.0: 1,
#  2209.0: 1,
#  2207.0: 1,
#  2231.0: 1,
#  2195.0: 1,
#  2186.0: 1,
#  2187.0: 1,
#  2188.0: 1,
#  2189.0: 1,
#  2190.0: 1,
#  2191.0: 1,
#  2192.0: 1,
#  2193.0: 1,
#  2194.0: 1,
#  2196.0: 1,
#  2206.0: 1,
#  2197.0: 1,
#  2198.0: 1,
#  2199.0: 1,
#  2200.0: 1,
#  2201.0: 1,
#  2202.0: 1,
#  2203.0: 1,
#  2204.0: 1,
#  2205.0: 1,
#  2230.0: 1,
#  2232.0: 1,
#  2184.0: 1,
#  2267.0: 1,
#  2258.0: 1,
#  2259.0: 1,
#  2260.0: 1,
#  2261.0: 1,
#  2262.0: 1,
#  2263.0: 1,
#  2264.0: 1,
#  2265.0: 1,
#  2266.0: 1,
#  2268.0: 1,
#  2256.0: 1,
#  2269.0: 1,
#  2270.0: 1,
#  2271.0: 1,
#  2272.0: 1,
#  2273.0: 1,
#  2274.0: 1,
#  2275.0: 1,
#  2276.0: 1,
#  2277.0: 1,
# ...

# %%
#Para automatizar el proceso el proceso anterior, se puede generar con un for loop, el
#  resultado final sería una lista de 3 diccionarios. Por lo tanto no tendríamos almacenados
#  cada diccionario en una variable. Habria que sacar cada diccionario por su indice de la
#  lista y almacenarlo en una variable.
lista_dicc=[]
for x in nombres_columnas:
    if attacks[x].dtypes=='object':
        pass
    else:
        lista_dicc.append(dict(attacks[x].value_counts()))

len(lista_dicc)
# Out:
# 3

# %% [markdown]
# - Cambiad el nombre de las columnas para que todas estén en minúsculas y reemplazad los espacios por _.

# %%
#Creamos un diccionario empleando una list comprehension para poner en minuscula los nombres de las columnas de todo el
#  dataframe y sustituir los espacios por "_".
columnas_nuevas={columna:columna.lower().replace(' ','_') for columna in attacks.columns}
columnas_nuevas
# Out:
# {'Unnamed: 0': 'unnamed:_0',
#  'Case Number': 'case_number',
#  'Year': 'year',
#  'Type': 'type',
#  'Country': 'country',
#  'Area': 'area',
#  'Location': 'location',
#  'Activity': 'activity',
#  'Name': 'name',
#  'Sex ': 'sex_',
#  'Age': 'age',
#  'Time': 'time',
#  'Species ': 'species_',
#  'Investigator or Source': 'investigator_or_source',
#  'pdf': 'pdf',
#  'href formula': 'href_formula',
#  'href': 'href',
#  'Case Number.1': 'case_number.1',
#  'Case Number.2': 'case_number.2',
#  'original order': 'original_order',
#  'Unnamed: 22': 'unnamed:_22',
#  'Unnamed: 23': 'unnamed:_23'}

# %%
#Empleando el diccionario creado se aplica el metodo ".rename()" para que se haga efectivo el cambio de nombre en las columnas.
attacks.rename(columns=columnas_nuevas, inplace=True)
attacks
# Out:
#       unnamed:_0   case_number    year          type    country  \
# 0              0    2018.06.25  2018.0       Boating        USA
# 1              1    2018.06.18  2018.0    Unprovoked        USA
# 2              2    2018.06.09  2018.0       Invalid        USA
# 3              3    2018.06.08  2018.0    Unprovoked  AUSTRALIA
# 4              4    2018.06.04  2018.0      Provoked     MEXICO
# ...          ...           ...     ...           ...        ...
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    area                          location  \
# 0            California       Oceanside, San Diego County
# 1               Georgia    St. Simon Island, Glynn County
# ...

# %% [markdown]
# - Eliminad las columnas de `Unnamed: 22` y `Unnamed: 23`, `Case Number.1`, `Case Number.2`, `original order`, `Investigator or Source`, `pdf`, `href formula`.

# %%
#Eliminamos las columnas indicadas con el metodo ".drop()".
eliminar_columnas_attacks=attacks.drop(['unnamed:_22','unnamed:_23','case_number.1','case_number.2','original_order','investigator_or_source','pdf','href_formula'],axis=1)
eliminar_columnas_attacks
# Out:
#       unnamed:_0   case_number    year          type    country  \
# 0              0    2018.06.25  2018.0       Boating        USA
# 1              1    2018.06.18  2018.0    Unprovoked        USA
# 2              2    2018.06.09  2018.0       Invalid        USA
# 3              3    2018.06.08  2018.0    Unprovoked  AUSTRALIA
# 4              4    2018.06.04  2018.0      Provoked     MEXICO
# ...          ...           ...     ...           ...        ...
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    area                          location  \
# 0            California       Oceanside, San Diego County
# 1               Georgia    St. Simon Island, Glynn County
# ...

# %% [markdown]
# - Establece la columna Case Number como índice del DataFrame.

# %%
eliminar_columnas_attacks.set_index(['case_number'],inplace=True)
eliminar_columnas_attacks
# Out:
#               unnamed:_0    year          type    country               area  \
# case_number
# 2018.06.25             0  2018.0       Boating        USA         California
# 2018.06.18             1  2018.0    Unprovoked        USA            Georgia
# 2018.06.09             2  2018.0       Invalid        USA             Hawaii
# 2018.06.08             3  2018.0    Unprovoked  AUSTRALIA    New South Wales
# 2018.06.04             4  2018.0      Provoked     MEXICO             Colima
# ...                  ...     ...           ...        ...                ...
# 1804.02.26.R        6127  1804.0          Boat  AUSTRALIA    New South Wales
# 1803.05.17          6128  1803.0  Sea Disaster        USA     South Carolina
# 1803.03.00          6129  1803.0    Unprovoked  AUSTRALIA  Western Australia
# 1802.04.13.R        6130  1802.0    Unprovoked      INDIA                NaN
# 1801.12.18.R        6131  1801.0      Provoked        NaN                NaN
#
# ...

# %% [markdown]
# 3. Guarda el csv que no tiene esas columnas para seguir usándolo mañana.

# %%
eliminar_columnas_attacks.to_csv('data_pandas_lec3/attacks_lec3.csv')

# %% [markdown]
# Happy coding 🦈
