# %% [markdown]
# # Ejercicios Pair Programming - Modulo 3 - Sprint 1
# ## Lección 8 - Encoding
# ### Pilar García Murillo y Sonia Ruiz Pérez

# %% [markdown]
# En el pair programming de hoy usaremos el set de datos que guardastéis en el pair programming de normalización y estandarización.
#
# Vuestro set de datos debería tener al menos una variable categórica, el objetivo del pair programming de hoy:
#
# - Hacer una codificación de la/las variables categóricas que tengáis en vuestro set de datos.
# - Recordad que lo primero que deberéis hacer es decidir su vuestras variables tienen o no orden, para que en función de esto uséis una aproximación u otra.
# - Guardad el dataframe, donde deberíais tener las variables estadandarizas, normalizadas y codificadas en un csv para usarlo en el próximo pairprogramming.
#
# Happy coding 🤯📊

# %%
# Importamos las librerías necesarias.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
pd.options.display.max_columns=None   #Para que se muestren todas las columnas de los dataframes.

# %%
#Creamos un dataframe con el csv de los datos de nuestro estudio.
df = pd.read_csv("files/taxis3_estandar.csv", index_col=0)
df.head(3)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
#
#             dropoff_zone pickup_borough dropoff_borough  tip_no_zeros  \
# 0    UN/Turtle Bay South      Manhattan       Manhattan  2.150000e+00
# 1  Upper West Side South      Manhattan       Manhattan  1.000000e-10
# 2           West Village      Manhattan       Manhattan  2.360000e+00
#
#      tip_box  passengers_robust  distance_robust  fare_robust  tolls_robust  \
# 0   0.787753                0.0        -0.022624    -0.294118           0.0
# 1 -10.996744                0.0        -0.389140    -0.529412           0.0
# 2   0.886769                0.0        -0.126697    -0.235294           0.0
#
#    total_robust
# 0     -0.127368
# 1     -0.511579
# 2      0.000000

# %% [markdown]
# `En nuestro dataframe tenemos las columnas categóricas color, payment, pickup_borough y dropoff_borough.`
# ` Que son a las que le vamos a realizar un encoding.`
# ` La vamos a dividir en dos grupos, las que tienen y las que no tienen orden en sus categorías.`

# %% [markdown]
# ### `Variables que no tienen orden.`
# #### `Color`
# `Color es una variable con dos categorías, 'yellow' y 'green'`
# ##### `Método a aplicar: One Hot Encoder`

# %%
#Creamos una función para aplicar el método One Hot Encoder.
def aplicar_one_hot_encoder(df, columna):
    # Iniciar el método
    ohe = OneHotEncoder(categories="auto", drop=None, dtype=np.int64)

    # Hacer la codificación de los datos para la variable a trasformar
    transformados = ohe.fit_transform(df[[columna]])

    # Convertir el array obtenido en un dataframe
    ohe_df = pd.DataFrame(transformados.toarray())

    # Obtener el nombre de las nuevas columnas
    ohe_df.columns = ohe.get_feature_names()

    # Concatenar el dataframe original con el dataframe obtenido
    df_unido = pd.concat([df, ohe_df], axis=1)

    # Eliminar columna original
    df_unido.drop(columna, axis=1, inplace=True)

    return df_unido

# %%
# Aplicamos la función
df = aplicar_one_hot_encoder(df, "color")

# %%
# Comprobamos el dataframe
df.head(3)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
#
#    tolls  total      payment            pickup_zone           dropoff_zone  \
# 0    0.0  12.95  credit card        Lenox Hill West    UN/Turtle Bay South
# 1    0.0   9.30         cash  Upper West Side South  Upper West Side South
# 2    0.0  14.16  credit card          Alphabet City           West Village
#
#   pickup_borough dropoff_borough  tip_no_zeros    tip_box  passengers_robust  \
# 0      Manhattan       Manhattan  2.150000e+00   0.787753                0.0
# 1      Manhattan       Manhattan  1.000000e-10 -10.996744                0.0
# 2      Manhattan       Manhattan  2.360000e+00   0.886769                0.0
#
#    distance_robust  fare_robust  tolls_robust  total_robust  x0_green  \
# 0        -0.022624    -0.294118           0.0     -0.127368         0
# 1        -0.389140    -0.529412           0.0     -0.511579         0
# 2        -0.126697    -0.235294           0.0      0.000000         0
#
#    x0_yellow
# 0          1
# 1          1
# 2          1

# %% [markdown]
# `Este método nos elimina la columna original color y ahora nos aparecen dos nuevas columnas, una por cada categorías llamadas x0_green y x0_yellow. El valor que toma cada celda es 1 si cumple la categoría y 0 si no la cumple.`

# %% [markdown]
# #### `Payment`
# `Payment es una variable con dos categorías, 'credit card' y 'cash'`
# ##### `Método a aplicar: get_dummies`

# %%
#Creamos una función para aplicar el método get_dummies.
def aplicar_get_dummies(df, columna):
    # Iniciar el método
    df_dummies = pd.get_dummies(df[columna], prefix_sep="_", prefix=columna, dtype=int)

    # Concatenar el dataframe original con el dataframe obtenido
    df_unido = pd.concat([df, df_dummies], axis=1)

    # Eliminar columna original
    df_unido.drop(columna, axis=1, inplace=True)

    return df_unido

# %%
# Aplicamos la función
df = aplicar_get_dummies(df, "payment")

# %%
# Comprobamos el dataframe
df.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total            pickup_zone           dropoff_zone pickup_borough  \
# 0    0.0  12.95        Lenox Hill West    UN/Turtle Bay South      Manhattan
# 1    0.0   9.30  Upper West Side South  Upper West Side South      Manhattan
# 2    0.0  14.16          Alphabet City           West Village      Manhattan
# 3    0.0  36.95              Hudson Sq         Yorkville West      Manhattan
# 4    0.0  13.40           Midtown East         Yorkville West      Manhattan
#
#   dropoff_borough  tip_no_zeros    tip_box  passengers_robust  \
# 0       Manhattan  2.150000e+00   0.787753                0.0
# 1       Manhattan  1.000000e-10 -10.996744                0.0
# 2       Manhattan  2.360000e+00   0.886769                0.0
# 3       Manhattan  6.150000e+00   1.945321                0.0
# 4       Manhattan  1.100000e+00   0.095650                2.0
#
#    distance_robust  fare_robust  tolls_robust  total_robust  x0_green  \
# 0        -0.022624    -0.294118           0.0     -0.127368         0
# 1        -0.389140    -0.529412           0.0     -0.511579         0
# 2        -0.126697    -0.235294           0.0      0.000000         0
# 3         2.737557     2.058824           0.0      2.398947         0
# 4         0.230769    -0.058824           0.0     -0.080000         0
#
#    x0_yellow  payment_cash  payment_credit card
# 0          1             0                    1
# 1          1             1                    0
# 2          1             0                    1
# 3          1             0                    1
# 4          1             0                    1

# %% [markdown]
# ### `Variables que tienen orden.`
# #### `pickup_borough`
# `pickup_borough es una variable con cuatro categorías, 'Manhattan', 'Queens', 'Brooklyn' y 'Bronx'.`
#
# `Tras realizar el test de ANOVA conocemos la fuerza de cada una de las categorías, siendo Queens la categoría con mayor efecto, seguido de Manhattan, Brooklyn y Bronx, por lo que vamos a darle un valor de 3 a la categoría con más efecto y 0 a la que menos.`
# ##### `Método a aplicar: Ordinal Encoding`

# %%
#Creamos una función para aplicar el método Ordinal Encoder.
def aplicar_ordinal_encoder(df, columna, orden_valores):
    # Iniciar el método
    oe = OrdinalEncoder(categories=[orden_valores], dtype=int)

    # Hacer la codificación de los datos para la variable a trasformar
    transformados_oe = oe.fit_transform(df[[columna]])

    # Convertir el array obtenido en un dataframe
    oe_df = pd.DataFrame(transformados_oe)

    # Cambiar el nombre de las nuevas columnas
    #oe_df.columns = oe.feature_names_in_

    columna += "_oe"

    # Sobreescribir la columna
    df[columna] = oe_df

    return df

# %%
#Creamos una variable con el orden de las variables según su fuerza de menor a mayor.
orden = ['Bronx', 'Brooklyn', 'Manhattan', 'Queens']

# %%
#Creamos un dataframe donde hemos aplicado el método Ordinal Encoder
df = aplicar_ordinal_encoder(df, "pickup_borough", orden)

# %%
#Comprobamos una muestra de 5 filas en el dataframe creado.
df.sample(5)
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 675   2019-03-11 20:48:45  2019-03-11 21:04:19           1      3.15  13.0
# 4261  2019-03-18 19:31:11  2019-03-18 19:52:53           1      8.32  25.5
# 5424  2019-03-09 11:30:01  2019-03-09 11:45:47           1      3.38  14.0
# 5451  2019-03-15 23:51:34  2019-03-15 23:55:06           1      1.01   5.0
# 5359  2019-03-17 16:52:33  2019-03-17 17:00:10           1      1.50   7.5
#
#        tip  tolls  total          pickup_zone                   dropoff_zone  \
# 675   3.36    0.0  20.16         East Village  Sutton Place/Turtle Bay North
# 4261  7.45    0.0  37.25       Midtown Center       Washington Heights North
# 5424  0.00    0.0  14.80          Fort Greene            Crown Heights South
# 5451  1.26    0.0   7.56    East Harlem South              East Harlem North
# 5359  2.15    0.0  12.95  Lincoln Square East          Upper East Side North
#
#      pickup_borough dropoff_borough  tip_no_zeros    tip_box  \
# 675       Manhattan       Manhattan  3.360000e+00   1.268436
# 4261      Manhattan       Manhattan  7.450000e+00   2.166499
# 5424       Brooklyn        Brooklyn  1.000000e-10 -10.996744
# 5451      Manhattan       Manhattan  1.260000e+00   0.233116
# 5359      Manhattan       Manhattan  2.150000e+00   0.787753
#
#       passengers_robust  distance_robust  fare_robust  tolls_robust  \
# 675                 0.0         0.678733     0.411765           0.0
# 4261                0.0         3.018100     1.882353           0.0
# 5424                0.0         0.782805     0.529412           0.0
# 5451                0.0        -0.289593    -0.529412           0.0
# 5359                0.0        -0.067873    -0.235294           0.0
#
#       total_robust  x0_green  x0_yellow  payment_cash  payment_credit card  \
# 675       0.631579         0          1             0                    1
# 4261      2.430526         0          1             0                    1
# 5424      0.067368         1          0             1                    0
# 5451     -0.694737         1          0             0                    1
# 5359     -0.127368         0          1             0                    1
#
#       pickup_borough_oe
# 675                   2
# 4261                  2
# 5424                  1
# 5451                  2
# 5359                  2

# %% [markdown]
# `Vemos que nos ha creado correctamente la nueva columna con el orden de valores especificados.`

# %% [markdown]
# #### `dropoff_borough`
# `dropoff_borough es una variable con cinco categorías, 'Manhattan', 'Queens', 'Brooklyn', 'Bronx' y 'Staten Island'.`
#
# `Tras realizar el test de ANOVA conocemos la fuerza de cada una de las categorías, siendo solo 'Staten Island' la categoría con  efecto, por lo que vamos a darle un valor de 1 a esta categoría y 0 al resto.`
# ##### `Método a aplicar: map`

# %%
#Creamos una función para aplicar el método map.
def aplicar_map(df, columna, diccionario):

    columna_nueva = columna + "_map"

    # Aplicar map
    df[columna_nueva] = df[columna].map(diccionario)

    return df

# %%
# Creamos el diccionario con los valores únicos 
mapa = {'Manhattan': 0, 'Queens': 0, 'Brooklyn': 0, 'Bronx': 0, 'Staten Island': 1}

# %%
# aplicamos la función
df = aplicar_map(df, "dropoff_borough", mapa)

# %%
#Comprobamos una muestra de 5 filas en el dataframe creado.
df.sample(5)
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 5653  2019-03-31 03:06:09  2019-03-31 03:10:06           1      0.80   5.0
# 263   2019-03-03 20:32:34  2019-03-03 20:39:11           1      0.77   6.0
# 2135  2019-03-27 09:56:17  2019-03-27 10:37:16           1      4.33  25.5
# 520   2019-03-26 17:03:17  2019-03-26 17:39:56           1      8.84  32.0
# 6160  2019-03-12 04:07:08  2019-03-12 04:19:08           1      3.93  13.5
#
#        tip  tolls  total        pickup_zone         dropoff_zone  \
# 5653  0.00   0.00   6.30    Jackson Heights      Jackson Heights
# 263   1.20   0.00  11.00       East Village  Little Italy/NoLiTa
# 2135  7.20   0.00  36.00        Murray Hill            Hudson Sq
# 520   0.00   5.76  42.06  LaGuardia Airport     Garment District
# 6160  5.26   0.00  22.81  East Harlem South       Midtown Center
#
#      pickup_borough dropoff_borough  tip_no_zeros    tip_box  \
# 5653         Queens          Queens  1.000000e-10 -10.996744
# 263       Manhattan       Manhattan  1.200000e+00   0.183568
# 2135      Manhattan       Manhattan  7.200000e+00   2.126898
# 520          Queens       Manhattan  1.000000e-10 -10.996744
# 6160      Manhattan       Manhattan  5.260000e+00   1.767347
#
#       passengers_robust  distance_robust  fare_robust  tolls_robust  \
# 5653                0.0        -0.384615    -0.529412          0.00
# 263                 0.0        -0.398190    -0.411765          0.00
# 2135                0.0         1.212670     1.882353          0.00
# 520                 0.0         3.253394     2.647059          5.76
# 6160                0.0         1.031674     0.470588          0.00
#
#       total_robust  x0_green  x0_yellow  payment_cash  payment_credit card  \
# 5653     -0.827368         1          0             1                    0
# 263      -0.332632         0          1             0                    1
# 2135      2.298947         0          1             0                    1
# 520       2.936842         0          1             1                    0
# 6160      0.910526         1          0             0                    1
#
#       pickup_borough_oe  dropoff_borough_map
# 5653                  3                    0
# 263                   2                    0
# 2135                  2                    0
# 520                   3                    0
# 6160                  2                    0

# %%
#Comprobamos si el recuento de valores únicos se corresponde al encoding creado.
df["dropoff_borough"].value_counts()
# Out:
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: dropoff_borough, dtype: int64

# %%
df["dropoff_borough_map"].value_counts()
# Out:
# 0    6339
# 1       2
# Name: dropoff_borough_map, dtype: int64

# %% [markdown]
# `Vamos a hacer un dict comprehension renombrando las columnas para guardarlas correctamente.`

# %%
#Comprobamos los nombres de la columnas.
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'pickup_zone', 'dropoff_zone', 'pickup_borough',
#        'dropoff_borough', 'tip_no_zeros', 'tip_box', 'passengers_robust',
#        'distance_robust', 'fare_robust', 'tolls_robust', 'total_robust',
#        'x0_green', 'x0_yellow', 'payment_cash', 'payment_credit card',
#        'pickup_borough_oe', 'dropoff_borough_map'],
#       dtype='object')

# %%
#hacemos una dict comprehension para después renombrar las columnas.
columnas_nuevas = {columna: columna.replace(" ", "_").lower() for columna in df.columns}

# %%
#Renombramos las columnas con la dict comprehension.
df.rename(columns=columnas_nuevas, inplace=True)

# %%
#Comprobamos que se han cambiado los nombres de la columnas.
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'pickup_zone', 'dropoff_zone', 'pickup_borough',
#        'dropoff_borough', 'tip_no_zeros', 'tip_box', 'passengers_robust',
#        'distance_robust', 'fare_robust', 'tolls_robust', 'total_robust',
#        'x0_green', 'x0_yellow', 'payment_cash', 'payment_credit_card',
#        'pickup_borough_oe', 'dropoff_borough_map'],
#       dtype='object')

# %%
#Guardamos el dataframe en un csv.
df.to_csv("files/taxis4_encoding.csv")
